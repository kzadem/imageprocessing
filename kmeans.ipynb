# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread("manzara.jpg")

# %%
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
pixel_values = image.reshape((-1, 3))

pixel_values = np.float32(pixel_values)

# %%
print(pixel_values.shape)
# Out:
# (1091840, 3)

# %%
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 100, 0.2)

# %%
k = 3
_, labels, (centers) = cv2.kmeans(pixel_values, k, None, criteria, 10, cv2.KMEANS_RANDOM_CENTERS)

# %%
centers = np.uint8(centers)

labels = labels.flatten()

# %%
segmented_image = centers[labels.flatten()]

# %%
segmented_image = segmented_image.reshape(image.shape)
plt.imshow(segmented_image)
plt.show()

# %%
segmentationimageone=cv2.divide(image,segmented_image, scale=256.0)

# %%
cv2.imwrite("segmentationimageone_off.png", segmentationimageone)
# Out:
# False

# %%
segmentationimageone = segmentationimageone.reshape((-1, 3))
cluster = 0
segmentationimageone[labels == cluster] = [0, 0, 0]
segmentationimageone = segmentationimageone.reshape(image.shape)
plt.imshow(segmentationimageone)
plt.show()

# %%
cv2.imwrite("segmentationimagetwo.png", segmentationimageone)
# Out:
# True

# %%
segmentationimageone = segmentationimageone.reshape((-1, 3))
cluster = 
segmentationimageone[labels == cluster] = [0, 0, 0]
segmentationimageone = segmentationimageone.reshape(image.shape)
plt.imshow(segmentationimageone)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-56-c10df8e3347e> in <module>
#       1 segmentationimageone = segmentationimageone.reshape((-1, 6))
#       2 cluster = 6
# ----> 3 segmentationimageone[labels == cluster] = [0, 0, 0]
#       4 segmentationimageone = segmentationimageone.reshape(image.shape)
#       5 plt.imshow(segmentationimageone)
#
# IndexError: boolean index did not match indexed array along dimension 0; dimension is 545920 but corresponding boolean dimension is 1091840
